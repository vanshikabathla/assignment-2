# %%
sum=0
for i in range(1,11):
    sum= sum +i
    print(sum)
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55

# %%
for i in range(1,11) :
    print(i*i)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100

# %%
for i in range(1,100):
    print(i**i) 
if i%4==0 and i%5==0:
    print("number is divisible by 4 and 5")
else:    
    print("number is not divisible by 4 and 5")
# Out:
# 1
# 4
# 27
# 256
# 3125
# 46656
# 823543
# 16777216
# 387420489
# 10000000000
# 285311670611
# 8916100448256
# 302875106592253
# 11112006825558016
# 437893890380859375
# 18446744073709551616
# 827240261886336764177
# 39346408075296537575424
# 1978419655660313589123979
# 104857600000000000000000000
# 5842587018385982521381124421
# 341427877364219557396646723584
# 20880467999847912034355032910567
# 1333735776850284124449081472843776
# 88817841970012523233890533447265625
# 6156119580207157310796674288400203776
# 443426488243037769948249630619149892803
# 33145523113253374862572728253364605812736
# 2567686153161211134561828214731016126483469
# 205891132094649000000000000000000000000000000
# 17069174130723235958610643029059314756044734431
# 1461501637330902918203684832716283019655932542976
# 129110040087761027839616029934664535539337183380513
# 11756638905368616011414050501310355554617941909569536
# 1102507499354148695951786433413508348166942596435546875
# ...

# %%
string = ("I want to become a data scientist: ")
vowels = 0
for i in string:
    if(i=='a' or i=='e' or i=='i'or i=='o' or i=='u'):
        vowels= vowels+1
        print("Total no. of vowels in a string = ", vowels)
# Out:
# Total no. of vowels in a string =  1
# Total no. of vowels in a string =  2
# Total no. of vowels in a string =  3
# Total no. of vowels in a string =  4
# Total no. of vowels in a string =  5
# Total no. of vowels in a string =  6
# Total no. of vowels in a string =  7
# Total no. of vowels in a string =  8
# Total no. of vowels in a string =  9
# Total no. of vowels in a string =  10
# Total no. of vowels in a string =  11
