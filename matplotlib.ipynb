# %%
1 Matplotlib is a cross-platform, data visualization and graphical plotting library for Python.
Matplotlib is a python library used to create 2D graphs and plots by using python scripts.

# %%
2 a graph in which the values of two variables are plotted along two axes

# %%
import numpy as np

# %%
np.random.seed(3)

# %%
import matplotlib.pyplot as plt

# %%
x = 3 + np.random.normal(0,2,50)
y = 3 + np.random.normal(0,2,len(x)) 
plt.scatter(x,y)
plt.xlabel("x axis")
plt.ylabel("y axis") 
plt.title("random data")
# Out:
# Text(0.5, 1.0, 'random data')

# %%
3 The subplot function deletes existing axes that overlap new axes.

# %%
import numpy as np

# %%
x = np.array([0,1,2,3,4,5]) 
y = np.array([0,100,200,300,400,500])

fig = plt.figure()
ax = fig.add_subplot() 
ax.scatter(x,y,)
ax.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 7
#       5 ax = fig.add_subplot()
#       6 ax.scatter(x,y,)
# ----> 7 ax.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'show'

# %%
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([50, 20, 40, 20, 60, 70])
fig = plt.figure()
ax = fig.add_subplot() 
ax.scatter(x,y,)
ax.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 6
#       4 ax = fig.add_subplot()
#       5 ax.scatter(x,y,)
# ----> 6 ax.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'show'

# %%
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([10, 20, 30, 40, 50, 60])

fig = plt.figure()
ax = fig.add_subplot() 
ax.scatter(x,y,)
ax.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 7
#       5 ax = fig.add_subplot()
#       6 ax.scatter(x,y,)
# ----> 7 ax.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'show'

# %%
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([200, 350, 250, 550, 450, 150])

fig = plt.figure()
ax = fig.add_subplot() 
ax.scatter(x,y,)
ax.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 7
#       5 ax = fig.add_subplot()
#       6 ax.scatter(x,y,)
# ----> 7 ax.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'show'

# %%
4  A barplot (or barchart) is one of the most common types of graphic. It shows the relationship between a numeric and a categoric variable.

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.bar(company , profit)
plt.companylabel("x axis")
plt.profitlabel("y axis")
plt.title("bar plot")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 4
#       2 profit = np.array([3000, 8000, 1000, 10000])
#       3 plt.bar(company , profit)
# ----> 4 plt.companylabel("x axis")
#       5 plt.profitlabel("y axis")
#       6 plt.title("bar plot")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'companylabel'

# %%
5 A box plot is a special type of diagram that shows the quartiles in a box and the line extending from the lowest to the highest value.
Box plots are used to show distributions of numeric data values, especially when you want to compare them between multiple groups.

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
np.random.seed(10)

# %%
dataSet = box1 = np.random.normal(100, 10, 200) ,box2 = np.random.normal(90, 20, 200)

plt.plot(box1,box2) 
plt.show()
